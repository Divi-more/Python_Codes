# %%
# 25 July 2026

# %%
#console: i/p, o/p or error show in it
#output:
#input: 'input()' is used to take STRING input only, not int or float
#print("Hello") 

user_input = input("Enter your msg:")
print("User message: ", user_input)

# %%
#Type conversion:

"""num1 = input("Enter num1")  #here input is taken as string not int
num2 = input("Enter num3")

res = num1 + num2
print(res)

output: 1020
"""

num1 = int(input("enter num1"))     #it convert string input into int while assignng it to num1
num2 = int(input("enter num2"))
res = num1 + num2
print(res)
# output = 30

# %%
#Decision Control:
"""
Decision Control:-help program to decide which code to execute
    1. if statement
    2. if else statement
    3. elif statement
    4. match (switch) case
    5. nested statement
"""
# 1. if statement:
#age= int(input("Enter age: "))
"""
if age>= 18:
    print("Eligible to vote...")
"""

# 2. if-else statement:
"""
if age>= 18:
    print("Eligible to vote...")
else:
    print("Not eligible")
"""


"""
# 3. elif statement:

marks = int(input("Enter marks: "))

if marks >= 75:
    print("Grade A")
elif marks >= 55:
    print("Grade B")
elif marks >= 35:
    print("Grade C")
else:
    print("Fail")

""" 

# 4. match case
"""
grade = "c"  # values are being assign to 'grade'

temp = grade.upper()

match temp:    # assigned values are mached with all cases, if matched -> it print it's statement  
    case "A":
        print("Marks are above 75")
    
    case "B":
        print("Marks are above 55")
        
    case "C":
        print("Marks are above 35")
        
    case _:
        print("Fail")
        
"""

# 5. nested statement:
"""
age = int(input("Enter age"))

nationality = "Indian"

if age >= 18:
    if nationality == "Indian":
        print("Eligible for voting")
    else:
        print("Not eligible")
else:
    print("age is not 18 or above")
"""

# %%
#Ternary operator: same as if-else but shorter form

age = int(input("Enter age: "))
print("Eligible for voting") if age >= 18 else print("Not eligible")

# %%
#Repetition Control Instructions (Loops)
"""
    1. while loop
    2. for loop
    3. range()
    4. break statement
    5. continue statement
    6. pass
    7. nested for
"""

# %%
"""
print("hello")
print("hello")
print("hello")
print("hello")
print("hello")

to avoid this we use loops
""" 

""" 
1. while loop syntax:-
while condition:
    block


i=1

while i <= 5:
    # i = 1
    # 1 < 5 true
    print("Hello")
    i += 1 #to avoid unconditional loop
    # 1 = 1 + 1........2     2 = 1 + 1
    # 2 = 2 + 1........3
"""
"""
2. for loop:-    

list1 = ["a","b","c","d","e"]

for i in list1:
    print("Hello") 
    #print("Hello", i)
    
#print("Hello",list1[2]) 

# 3. range():-
for i in range(1, 11):      #print till 11 not 11
# 1, 2, 3, 4, .......10    
    print(i * 5)        #print(i)
"""
    
"""    
4. break statement: stops the loop.

for i in range(1,11):
    if i == 5:      # 5 == 5, true. loop stop execution 
        break
    print(i)

# 5. continue statement:-
for i in range(1,11):
    if i == 5:  # 5 == 5, true. 5 skip and then continue ahead. 
        #if i % 2 == 0: 
        continue
    print(i)

# 6. pass
def add():
    pass    #does nothing, when we keep something empty.
add()
 
# 7. nested for
for i in range(1,4):
    for j in range(2,5):
        print(j, end=" ")   #print("*", end=" ")
        
    print("\n")
"""   

"""
col = 3
row = 3
for i in range(col):
    for j in range(row):
        print("*", end=" ")   #print("*", end=" ")
    print("")
    row -= 1
"""
col = 3
row = 1
for i in range(col):
    for j in range(row):
        print("*", end=" ")   #print("*", end=" ")
    print("")
    row += 1
