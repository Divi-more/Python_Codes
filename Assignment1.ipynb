# %%
#21 July 2026

# %%
# Q1. Write a Python program to store the following information 
# using variables and display it in a well-formatted way. 
# • Name  • Age  • College Name  • City  • Course Name 

name = "Divya"
age = 21
college_name = "SVCET College"
city = "Pune City"
course_name = "Computer Engineering"

print("Name:", name)
print("Age:", age)
print("College Name:", college_name)
print("City:", city)
print("Course Name:", course_name)
# Out:
# Name: Divya
# Age: 21
# College Name: SVCET College
# City: Pune City
# Course Name: Computer Engineering

# %%
# Q2. Student Report: Create variables for the following student 
# details and print them: • Student Name  • Roll Number  
# • Branch  • Percentage  • Passed (True/False) 

student_name = "Divya More"
roll_number = 18
branch = "Computer Engineering"
percentage = 85.5
passed = True

print("\nStudent Report:")
print("Student Name:", student_name)
print("Roll Number:", roll_number)
print("Branch:", branch)
print("Percentage:", percentage)
print("Passed:", passed)
# Out:
# Student Report:
# Student Name: Divya More
# Roll Number: 18
# Branch: Computer Engineering
# Percentage: 85.5
# Passed: True

# %%
# Q3. Identifier Practice: Create 10 valid identifiers related to a 
# college management system (for example: student_name, roll_no, etc.)  
#and assign appropriate values to them. Then print all the variables.

student_name = "Divya More"
roll_no = 18
branch = "Computer Engineering"
year = 4
semester = 1
course_code = "CS101"
course_name = "Introduction to Programming"
student_email = "divyamore@gmail.com"
student_phone = "8080071215"

print("Name          : ",student_name)
print("Roll No       : ",roll_no)
print("Branch        : ",branch)
print("Year          : ",year)
print("Semester      : ",semester)
print("Course Code   : ",course_code)
print("Course Name   : ",course_name)
print("Student Email : ",student_email)
print("Student Phone : ",student_phone)
# Out:
# Name          :  Divya More
# Roll No       :  18
# Branch        :  Computer Engineering
# Year          :  4
# Semester      :  1
# Course Code   :  CS101
# Course Name   :  Introduction to Programming
# Student Email :  divyamore@gmail.com
# Student Phone :  8080071215

# %%
# Q4. Comments Practice Write a Python program that contains:
# • At least 3 single-line comments  • 1 multi-line comment 
# • A program that prints a short introduction about yourself. 

"""
This program demonstrates the use of comments in Python.
It includes single-line comments, a multi-line comment, and a simple print statement.
"""

print("Hello! My name is Divya More.")
print("I am a student of Computer Engineering at SVCET College in Pune City.")
print("I am passionate about programming and technology.") #It can be written in a single line comment too
# Out:
# Hello! My name is Divya More.
# I am a student of Computer Engineering at SVCET College in Pune City.
# I am passionate about programming and technology.

# %%
"""
Q5. Correct the Errors Rewrite the following invalid variable names 
into valid Python identifiers and assign appropriate values to them. 
• 2student • student-name • student name • class • for • employee@id 
"""

student2 = "Sanavi Rahane"
student_name = "Sanavi Rahane"
student_name = "Sanavi Rahane"
class_name = "Computer"
for_loop = "10"
employee_id = "101"

print("Student 2:", student2)
print("Student Name:", student_name)    
print("Class Name:", class_name)
print("For Loop:", for_loop)
print("Employee ID:", employee_id)
# Out:
# Student 2: Sanavi Rahane
# Student Name: Sanavi Rahane
# Class Name: Computer
# For Loop: 10
# Employee ID: 101
