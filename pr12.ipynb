# %% [markdown]
# ### 11 Aug, 2026

# %% [markdown]
# ### Python File input/output:-
#
#     1. File I/O:- process of reading data from a file and writing data to a file using a program.
#
#     2. Types of file:-
#         i) Text file:- .txt, .csv, .json
#         ii) binary file:- .jpg, .png, .mp3
#
#     3. open() - open a file and create a connection between file and python code
#
#     4.

# %%
# open():

str1 = "Hello user"
str2 = "Hello user 2"

# if file exist-> open, if not-> cretes
# fobj = open("temp.txt", "w")
# fobj.write(str1)
# fobj.write(str2) # will overwrite str1 and print str2

fobj = open("temp.txt", "a")
print("")
fobj.write(str1)
# fobj.write(str2)

fobj.close()
