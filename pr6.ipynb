# %% [markdown]
# 28 July 2026

# %% [markdown]
# 3. Tuples:- collection data types used to store muliple values in single variables. Written inside ().
#
#     # Charecteristics:
#         1. ordered
#         2. immutable - can't change (No append())
#         3. indexed - can access through index
#         4. slicing supported
#         5. iterable
#         6. allows duplication
#         7. heterogenous-(Multiple data types) and homogeneous-(Single data type)
#         8. nensted support - tuple inside tuple
#         9. +ve and -ve indexing
#         10. concatination
#         11. repetition

# %%
tuple1 = ("user1", "user2", "user3","user2", "user3")   # allows duplicate      - Homogeneous
# print(tuple1) #ordered

# print(tuple1[0]) #indexed

# # [ start : end : step ]
# print(tuple1[0 : 2])    #slicing
# print(tuple1[1: ])      #start from index '1'
# print(tuple1[: 2])      #print till index 2, ignores 2 as it print till 2
# print(tuple1[ : ])
# print(tuple1[ : : 2])
# print(tuple1[ : : -1])

# for i in tuple1:      #iteration
#     print(i, end=" ")
# for i, j in enumerate(tuple1):
#     if i == 1:
#         continue
#     print(j)

# newT = ("user1", "user2", 1,10,True)    #heterogeneous
# print(newT)

# tuple1 = ("user1", "user2", "user3",("user2", "user3"))   #nested support
# print(tuple1)
# print(len(tuple1))   
   
# print(tuple1[2])    # +ve indexing
# print(tuple1[-3])   # -ve indexing
 
# tuple2 = ("User5", "User6")
# print(tuple1 + tuple2)

# %% [markdown]
# Methods:
#     1. count() - return no. of occurences
#     2. index() - return index number of given value

# %%
tuple1 = ("user1", "user2", "user3","user2", "user3")

print(tuple1.count("user2"))  


print(tuple1.index("user2"))
# Out:
# 2
# 1

# %% [markdown]
# Built-In Functions:
#     1. len()
#     2. max()
#     3. min()
#     4. sum()
#     5. sorted()
#     6. type()
#     7. tuple()
#     8. list()
#     9. set()
#     10. str()
#     11. enumerate()
#     12. reversed()
#     13. any()
#     14. all()

# %%
tuple1 = ("user1", "user2", "user3","user2", "user3")
# tuple2 = ("demo", "user")
tuple3 = (20,30,10)
# print(len(tuple1))

# print(max(tuple2))
# print(min(tuple2))

# print(sum(tuple3))  or
# temp = 0
# for i in tuple3:
#     temp += i
# print(temp)

# print(sorted(tuple3))    # sorted

# print(type(tuple1))

# print(list(tuple1))   #list

# print(set(tuple1))    #set

# print(str(tuple1))    #str
# str1 = str(tuple1)
# print(str1)
# print(str1[0])    #OR    print(str(tuple1)[0])


#enumerate():- index and value both
# print(tuple1)
# for i in tuple1:      # gives only value
#     print(i)
# for i, j in enumerate(tuple1):    # gives index and value both
#     print(i, j)     # i = index, j - value

# print(reversed(tuple1))
# tup = reversed(tuple1)
# print(" ".join(tup))

# temp = tuple(reversed(tuple3))
# print(temp)
# Out:
# (10, 30, 20)

# %% [markdown]
# # Set: - written inside {}
#
# # Characteristics / properties:
#     1. unordered
#     2. mutable - can change / mutable set but elements are immutable
#     3. unindexed
#     4. no duplicate allowed
#     5. iterable
#     6. Heterogenous
#     7. Homogeneous
#     8. nested set not allowed - but tuple is allowed only, neither nested set nor nested list
#     9. fast searching
#     10. uses hashing techniques, dynamic
#     11. no slicing, no +ve and -ve indexing
#     12. support mathematicals operation

# %%
# set1 = {"one", "two", "three"}
# print(set1)

# set1.add("four")
# print(set1)

# for i in set1:
#     print(i, end=" ")
    
set1 = {"one", "two", "three", (1, 3)}    #heterogenous
print(set1)
# Out:
# {'one', 'three', (1, 3), 'two'}

# %% [markdown]
# # Methods:-
#     1. add()
#     2. update() - to add multiple values
#     3. removed() - removes single value
#     4. discard() -
#     5. pop() - removes random element
#     6. clear()
#     7. copy()
#     8. union()
#     9. intersection()

# %%
set1 = {"one", "two", "three"}    
# print(set1)

set1.add("four")
print(set1)

# set1.update({"user1","user2"})        # or 
# print(set1)

# print(set1)
# set1.remove("two")
# set1.discard("five")
# print(set1)

# set1.pop()

# set1.clear()

# temp = set1.copy()
# print(temp)

# temp2 = set1
# print(temp2)

set2 = {1,3,7}
# print(set2)
set3 = set2.union(set1)
# print(set3)
# print(set1.union(set2))

print(set2.intersection(set3))

print(set3.difference(set2))
# Out:
# {'one', 'three', 'two', 'four'}
# {1, 3, 7}
# {'one', 'three', 'two', 'four'}

# %% [markdown]
# # Built-In Functions
#     1. len()
#     2. max()
#     3. min()
#     4. sum()
#     5. sorted()
#     6. type()
#     7. set()
#     8. list()
#     9. tuple()
#     10. str()
#     11. enumerate()
#     12. any()
#     13. all()

# %%
set1 = {"one", "two", "three"}    
print(set1)

# print(len(set1))

# print(max(set1))

# print(min(set1))

# set2 = {1,4,2,3}
# print(sum(set2))

# print(sorted(set1))
# print(sorted(set2))

# print(type(set1))
# print(type(set2))

# print("list: ",list(set1))

# print("tuple: ",tuple(set1))

# print("string: ",str(set1))

# for i, j in enumerate(set1):
#     print(i,j)
# Out:
# {'one', 'three', 'two'}
# 0 one
# 1 three
# 2 two
