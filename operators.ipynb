# %%
#23/07/2026
#Operators: special symbols that perform operations on variables and values

#Assinment operators
#1. = (Euqal to): right side assign to left side
usern_name = "Divya"        # Divya value assign to user_name variable
print (usern_name,"\n")

#2. += (add & assign): 
num1 = 10
# num1 = num1 + 5
# num1 += 5
# print(num1,"\n")

#3. -= (subtract & assign):
num1 -= 5       # num1 = num1 - 5   =5
print(num1,"\n")

#4. *= (multiply & assign):
num2 = 15
num2 *= 2
print(num2) 

#5. /=
#6. 
#7
# Out:
# Divya
#
# 5
# 30

# %%
#Arithmetic
#+, -, *, /, //, %, **(exponent)
res = 10 // 3
print(res)

n1=2
n2=2
ress=n1**n2
print(ress)
# Out:
# 1
# 4

# %%
#Comparison operator
# ==, !=, >, <, >=, <= (result- T or F)
print(10==20)
print(5==5)

print(10!=20)
print(10!=10)

print(2<5)

print(10>8)

print(5<=5)

print(1>=9)
# Out:
# False
# True
# True
# False
# True
# True
# True
# False

# %%
#Logical operator
#1. and: if both are true
# age=10
# nationality="indian"
# if(age>=18 and nationality=="indian"):
#     print("allow to vote")
# else:
#     print("Not allow")
    
#2. or: any one true
# if(age>=18 or nationality=="indian"):
#     print("allow to vote")
# else:
#     print("Not allow")    

#3. not: true -> false
age=10
if age >= 18:       #if not age >= 18:
    print("allow to vote")
else:
    print("not allow")
# Out:
# allow to vote

# %%
#Identity operator
# is, is not:

n1=20
n2=20
print(id(n1))
print(id(n2))

print(n1 is not n2) #is


# demolist=[1,2,3]
# temp=id(demolist)
# demolist.append(4)
# Out:
# 140734592222936
# 140734592222936
# False

# %%
#membership operator: in, not in

user="user demo"
print("e" in user)

print("z" not in user) #alter result
# Out:
# True
# True
