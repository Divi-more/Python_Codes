# %%
str1 = "   This is my magic function   "

str1 = str1.strip().split()

str2 = str1[-1]
print("Last word of the sentence: ", str2)

length = len(str2)

print("Length of last word is: ",length)
# Out:
# Last word of the sentence:  function
# Length of last word is:  8

# %%
str1 = "abbedddd"
first=[]
last=[]
for i in str1:
    if i == str1[-1]:
        first.append(i)
    else:
        last.append(i)

print("".join(first+last))
# Out:
# ddddabbe
